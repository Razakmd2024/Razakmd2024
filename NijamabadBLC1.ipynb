# %% [markdown]
# <a href="https://colab.research.google.com/github/Razakmd2024/Razakmd2024/blob/main/NijamabadBLC1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Extracting data from National Panchayat awards Web portal

# %%
import pandas as pd
import numpy as np
from pandas import read_html
import matplotlib.pyplot as plt
import seaborn as sns
### Mandal Wise BPPAC URLs ###
url_1="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5752&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_2="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5753&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_3="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5755&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_4="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5759&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_5="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=289996&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_6="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5760&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_7="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5761&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_8="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=289989&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_9="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5764&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_10="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5767&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_11="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5768&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_12="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5772&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_13="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=289990&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_14="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5773&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_15="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=289995&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_16="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=289991&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_17="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=289992&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_18="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5775&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_19="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5776&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_20="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5777&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_21="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5780&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_22="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=289993&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_23="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5782&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_24="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5784&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_25="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5785&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_26="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=5786&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"
url_27="https://panchayataward.gov.in/villageThemeCommitteeReport.do?stateCode=36&localBodyCode=289994&parentLb=471&OWASP_CSRFTOKEN=WVLJ-FQFJ-WMW3-BI07-H2A5-5SD2-JO2W-B71M"

# 1_MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_1)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(18)
df_pdp.to_csv('one.csv', header=False, index=False)
df_1=pd.read_csv('one.csv', names=col)
df_1['Mandal']='ARMOOR'
df_1=df_1.replace("Yes",1)
df_1=df_1.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_1.drop(del_col1, axis=1, inplace=True)
 
# 2_MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_2)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(10)
df_pdp.to_csv('two.csv', header=False, index=False)
df_2=pd.read_csv('two.csv', names=col)
df_2['Mandal']='BALKONDA'
df_2=df_2.replace("Yes",1)
df_2=df_2.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_2.drop(del_col1, axis=1, inplace=True)
#print(df_2.groupby('Mandal').sum())

# 3 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_3)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(27)
df_pdp.to_csv('three.csv', header=False, index=False)
df_3=pd.read_csv('three.csv', names=col)
df_3['Mandal']='BHEEMGAL'
df_3=df_3.replace("Yes",1)
df_3=df_3.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_3.drop(del_col1, axis=1, inplace=True)


# 4 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_4)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(38)
df_pdp.to_csv('four.csv', header=False, index=False)
df_4=pd.read_csv('four.csv', names=col)
df_4['Mandal']='BODHAN'
df_4=df_4.replace("Yes",1)
df_4=df_4.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_4.drop(del_col1, axis=1, inplace=True)


# 5 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_5)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(5)
df_pdp.to_csv('five.csv', header=False, index=False)
df_5=pd.read_csv('five.csv', names=col)
df_5['Mandal']='Chandur'
df_5=df_5.replace("Yes",1)
df_5=df_5.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_5.drop(del_col1, axis=1, inplace=True)


# 6 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_6)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(22)
df_pdp.to_csv('six.csv', header=False, index=False)
df_6=pd.read_csv('six.csv', names=col)
df_6['Mandal']='DHARPALLE'
df_6=df_6.replace("Yes",1)
df_6=df_6.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_6.drop(del_col1, axis=1, inplace=True)


# 7 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_7)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(34)
df_pdp.to_csv('SEVEN.csv', header=False, index=False)
df_7=pd.read_csv('SEVEN.csv', names=col)
df_7['Mandal']='DICHPALLE'
df_7=df_7.replace("Yes",1)
df_7=df_7.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_7.drop(del_col1, axis=1, inplace=True)


# 8 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_8)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(23)
df_pdp.to_csv('EIGHT.csv', header=False, index=False)
df_8=pd.read_csv('EIGHT.csv', names=col)
df_8['Mandal']='INDALWAI'
df_8=df_8.replace("Yes",1)
df_8=df_8.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_8.drop(del_col1, axis=1, inplace=True)


# 9 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_9)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(21)
df_pdp.to_csv("NINE.csv", header=False, index=False)
df_9=pd.read_csv('NINE.csv', names=col)
df_9['Mandal']='JAKRANPALLE'
df_9=df_9.replace("Yes",1)
df_9=df_9.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_9.drop(del_col1, axis=1, inplace=True)


## 10 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_10)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(14)
df_pdp.to_csv('TEN.csv', header=False, index=False)
df_10=pd.read_csv('TEN.csv', names=col)
df_10['Mandal']='KAMMARAPALLE'
df_10=df_10.replace("Yes",1)
df_10=df_10.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_10.drop(del_col1, axis=1, inplace=True)
#print(df_pd.groupby('Mandal').sum())


# 11 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_11)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(28)
df_pdp.to_csv('11.csv', header=False, index=False)
df_11=pd.read_csv('11.csv', names=col)
df_11['Mandal']='KOTGIRI'
df_11=df_11.replace("Yes",1)
df_11=df_11.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_11.drop(del_col1, axis=1, inplace=True)


# 12 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_12)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(30)
df_pdp.to_csv('12.csv', header=False, index=False)
df_12=pd.read_csv('12.csv', names=col)
df_12['Mandal']='MAKLOOR'
df_12=df_12.replace("Yes",1)
df_12=df_12.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_12.drop(del_col1, axis=1, inplace=True)


# 13 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_13)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(11)
df_pdp.to_csv('13.csv', header=False, index=False)
df_13=pd.read_csv('13.csv', names=col)
df_13['Mandal']='MENDORA'
df_13=df_13.replace("Yes",1)
df_13=df_13.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_13.drop(del_col1, axis=1, inplace=True)


# 14 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_14)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(10)
df_pdp.to_csv('14.csv', header=False, index=False)
df_14=pd.read_csv('14.csv', names=col)
df_14['Mandal']='MORTAD'
df_14=df_14.replace("Yes",1)
df_14=df_14.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_14.drop(del_col1, axis=1, inplace=True)

# 15 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_15)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(5)
df_pdp.to_csv('15.csv', header=False, index=False)
df_15=pd.read_csv('15.csv', names=col)
df_15['Mandal']='MOSARA'
df_15=df_15.replace("Yes",1)
df_15=df_15.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_15.drop(del_col1, axis=1, inplace=True)
 
# 16 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_16)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(21)
df_pdp.to_csv('16.csv', header=False, index=False)
df_16=pd.read_csv('16.csv', names=col)
df_16['Mandal']='MUGPAL'
df_16=df_16.replace("Yes",1)
df_16=df_16.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_16.drop(del_col1, axis=1, inplace=True)
#print(df_16.groupby('Mandal').sum())

# 17 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_17)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(7)
df_pdp.to_csv('17.csv', header=False, index=False)
df_17=pd.read_csv('17.csv', names=col)
df_17['Mandal']='MUPKAL'
df_17=df_17.replace("Yes",1)
df_17=df_17.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_17.drop(del_col1, axis=1, inplace=True)


# 18 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_18)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(33)
df_pdp.to_csv('18.csv', header=False, index=False)
df_18=pd.read_csv('18.csv', names=col)
df_18['Mandal']='NANDIPET'
df_18=df_18.replace("Yes",1)
df_18=df_18.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_18.drop(del_col1, axis=1, inplace=True)


# 19 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_19)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(32)
df_pdp.to_csv('19.csv', header=False, index=False)
df_19=pd.read_csv('19.csv', names=col)
df_19['Mandal']='NAVIPET'
df_19=df_19.replace("Yes",1)
df_19=df_19.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_19.drop(del_col1, axis=1, inplace=True)


# 20 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_20)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(19)
df_pdp.to_csv('20.csv', header=False, index=False)
df_20=pd.read_csv('20.csv', names=col)
df_20['Mandal']='NIZAMABAD'
df_20=df_20.replace("Yes",1)
df_20=df_20.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_20.drop(del_col1, axis=1, inplace=True)


# 21 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_21)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(17)
df_pdp.to_csv('21.csv', header=False, index=False)
df_21=pd.read_csv('21.csv', names=col)
df_21['Mandal']='RENJAL'
df_21=df_21.replace("Yes",1)
df_21=df_21.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_21.drop(del_col1, axis=1, inplace=True)


# 22 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_22)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(10)
df_pdp.to_csv('22.csv', header=False, index=False)
df_22=pd.read_csv('22.csv', names=col)
df_22['Mandal']='RUDRUR'
df_22=df_22.replace("Yes",1)
df_22=df_22.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_22.drop(del_col1, axis=1, inplace=True)


# 23 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_23)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(30)
df_pdp.to_csv('23.csv', header=False, index=False)
df_23=pd.read_csv('23.csv', names=col)
df_23['Mandal']='SIRKONDA'
df_23=df_23.replace("Yes",1)
df_23=df_23.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_23.drop(del_col1, axis=1, inplace=True)


## 24 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_24)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(22)
df_pdp.to_csv('24.csv', header=False, index=False)
df_24=pd.read_csv('24.csv', names=col)
df_24['Mandal']='VARNI'
df_24=df_24.replace("Yes",1)
df_24=df_24.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_24.drop(del_col1, axis=1, inplace=True)
#print(df_pd.groupby('Mandal').sum())


# 25 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_25)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(18)
df_pdp.to_csv('25.csv', header=False, index=False)
df_25=pd.read_csv('25.csv', names=col)
df_25['Mandal']='VELPUR'
df_25=df_25.replace("Yes",1)
df_25=df_25.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_25.drop(del_col1, axis=1, inplace=True)


# 26 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_26)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(17)
df_pdp.to_csv('26.csv', header=False, index=False)
df_26=pd.read_csv('26.csv', names=col)
df_26['Mandal']='YEDAPALLE'
df_27=df_26.replace("Yes",1)
df_26=df_26.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_26.drop(del_col1, axis=1, inplace=True)


# 27 MANDAL REPORT ##
col = ['GP/VC Name(Gram Panchayat Code)','PFELP_BPPAC_Status','PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_BPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_BPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_BPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_BPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_BPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_BPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_BPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_BPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_pdp=pd.io.html.read_html(url_27)
df_pdp=df_pdp[0]
df_pdp.columns = df_pdp.columns.droplevel()
del_col=['S.No','Unnamed: 29_level_1','Unnamed: 30_level_1','Unnamed: 31_level_1','Unnamed: 32_level_1','Unnamed: 33_level_1','Unnamed: 34_level_1','Unnamed: 35_level_1','Unnamed: 36_level_1','Unnamed: 37_level_1','Unnamed: 38_level_1']
df_pdp=df_pdp.drop(del_col, axis=1)
df_pdp=df_pdp.drop(8)
df_pdp.to_csv('27.csv', header=False, index=False)
df_27=pd.read_csv('27.csv', names=col)
df_27['Mandal']='YERGATLA'
df_27=df_27.replace("Yes",1)
df_27=df_27.replace('No',0)
del_col1=['PFELP_DPPAC_Status','PFELP_SPPAC_Status','HP_DPPAC_Status','HP_SPPAC_Status','CFP_DPPAC_Status','CFP_SPPAC_Status','WSP_DPPAC_Status','WSP_SPPAC_Status','CGP_DPPAC_Status','CGP_SPPAC_Status','SSIP_DPPAC_Status','SSIP_SPPAC_Status','SSP_DPPAC_Status','SSP_SPPAC_Status','PWGG_DPPAC_Status','PWGG_SPPAC_Status','WFPV_DPPAC_Status','WFPV_SPPAC_Status']
df_27.drop(del_col1, axis=1, inplace=True)


## Concatenate Mandals
frames = [df_1, df_2,df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18, df_19, df_20, df_21, df_22, df_23, df_24, df_25, df_26, df_27]
mdl_concat= pd.concat(frames)
sum_col=['PFELP_BPPAC_Status','HP_BPPAC_Status', 'CFP_BPPAC_Status', 'WSP_BPPAC_Status','CGP_BPPAC_Status', 'SSIP_BPPAC_Status', 'SSP_BPPAC_Status','PWGG_BPPAC_Status', 'WFPV_BPPAC_Status']
mdl_concat['Total']=np.sum(mdl_concat[sum_col], axis=1)
result= mdl_concat.groupby('Mandal').sum()

result['% of Recommended']=round(result['Total']/27*100,2)
gps=mdl_concat[mdl_concat["Total"] != 0]
print(result)

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('BPPAC_Recommendation.xlsx')

# Write each dataframe to a different worksheet.
result.to_excel(writer, sheet_name='Abstract')
mdl_concat.to_excel(writer, sheet_name='GP_Wise')
gps.to_excel(writer, sheet_name='GPs_Recommended')


# Close the Pandas Excel writer and output the Excel file.
writer.save()


#plt.figure(figsize=(64,8))
result.drop(["Total","% of Recommended"], axis=1).plot(kind='bar', stacked=True,figsize=(22,6))
plt.legend(loc=(1.5,0.5))
plt.title("BLC Committee Recommendation Status Report", fontsize=32)
plt.xlabel("Mandal Name",fontsize=22)
plt.xticks(fontsize=22)
plt.tight_layout()
plt.savefig("BlcRec.jpeg")
"""gps.sort_values(by='Total', ascending=True).drop(['Total'],axis=1).plot(x='GP/VC Name(Gram Panchayat Code)',kind='barh', stacked=True, figsize=(12,64))
plt.xlim(0,9)
plt.xlabel("No. of. Themes")
plt.ylabel("GP_Name",fontsize=14)
plt.title ("GP Wise Recommendations for Panchayat Awards")
plt.legend (loc=(0.5,0.5))
plt.tight_layout()
plt.savefig("gpwise.pdf")"""
plt. show ()
# Out:
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:84: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return reduction(axis=axis, out=out, **passkwargs)
#               PWGG_BPPAC_Status  Total  % of Recommended
# Mandal
# ARMOOR                        3      3             11.11
# BALKONDA                      3      3             11.11
# BHEEMGAL                      3      3             11.11
# BODHAN                        3      3             11.11
# Chandur                       3      3             11.11
# DHARPALLE                     0      0              0.00
# DICHPALLE                     3      3             11.11
# INDALWAI                      0      0              0.00
# JAKRANPALLE                   3      3             11.11
# KAMMARAPALLE                  3      3             11.11
# KOTGIRI                       3      3             11.11
# MAKLOOR                       3      3             11.11
# MENDORA                       3      3             11.11
# MORTAD                        3      3             11.11
# MOSARA                        0      0              0.00
# MUGPAL                        0      0              0.00
# MUPKAL                        3      3             11.11
# NANDIPET                      3      3             11.11
# NAVIPET                       3      3             11.11
# NIZAMABAD                     0      0              0.00
# RENJAL                        0      0              0.00
# RUDRUR                        3      3             11.11
# SIRKONDA                      0      0              0.00
# VARNI                         0      0              0.00
# VELPUR                        3      3             11.11
# YEDAPALLE                     0      0              0.00
# YERGATLA                      3      3             11.11
